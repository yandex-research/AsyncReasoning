# %%
# %env CUDA_VISIBLE_DEVICES=0
# %env HF_HOME=/mnt/LLM
# %env OMP_NUM_THREADS=16

# %%
# You might have to install FFMpeg on your system
# !sudo apt install ffmpeg

# %%
import sys; sys.path.insert(0, "../.");

from evals.voice_assistant import VoiceAssistant

# %%
demo = VoiceAssistant(tokens_per_chunk=10)

# %%
demo.display()
